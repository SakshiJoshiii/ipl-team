# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **BATTING DATASET**

# %%
bat16  = pd.read_csv('/content/drive/MyDrive/Batting Stats/BATTING STATS - IPL_2016.csv')
bat17  = pd.read_csv('/content/drive/MyDrive/Batting Stats/BATTING STATS - IPL_2017.csv')
bat18  = pd.read_csv('/content/drive/MyDrive/Batting Stats/BATTING STATS - IPL_2018.csv')
bat19  = pd.read_csv('/content/drive/MyDrive/Batting Stats/BATTING STATS - IPL_2019.csv')
bat20  = pd.read_csv('/content/drive/MyDrive/Batting Stats/BATTING STATS - IPL_2020.csv')
bat21  = pd.read_csv('/content/drive/MyDrive/Batting Stats/BATTING STATS - IPL_2021.csv')
bat22  = pd.read_csv('/content/drive/MyDrive/Batting Stats/BATTING STATS - IPL_2022.csv')
bat16['Year'] = 2016
bat17['Year'] = 2017
bat18['Year'] = 2018
bat19['Year'] = 2019
bat20['Year'] = 2020
bat21['Year'] = 2021
bat22['Year'] = 2022
bat = pd.concat([bat16, bat17, bat18, bat19, bat20, bat21, bat22])
bat
# Out:
#      POS               Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  \
# 0      1          Virat Kohli   16    16   4   973   113  81.08  640  152.03
# 1      2         David Warner   17    17   3   848   93*  60.57  560  151.42
# 2      3       AB de Villiers   16    16   3   687  129*  52.84  407  168.79
# 3      4       Gautam Gambhir   15    15   2   501   90*  38.53  411  121.89
# 4      5       Shikhar Dhawan   17    17   4   501   82*  38.53  429  116.78
# ..   ...                  ...  ...   ...  ..   ...   ...    ...  ...     ...
# 157  158     Fazalhaq Farooqi    3     1   1     2    2*      -    8   25.00
# 158  159   Jagadeesha Suchith    5     2   0     2     2      1    8   25.00
# 159  160          Tim Southee    9     5   1     2    1*    0.5   12   16.66
# 160  161  Nathan Coulter-Nile    1     1   1     1    1*      -    2   50.00
# 161  162        Anrich Nortje    6     1   1     1    1*      -    6   16.66
#
#      100  50  4s  6s  Year
# ...

# %% [markdown]
# **BOWLING DATASET**

# %%
ball16  = pd.read_csv('/content/drive/MyDrive/Bowling Stats/BOWLING STATS - IPL_2016.csv')
ball17  = pd.read_csv('/content/drive/MyDrive/Bowling Stats/BOWLING STATS - IPL_2017.csv')
ball18  = pd.read_csv('/content/drive/MyDrive/Bowling Stats/BOWLING STATS - IPL_2018.csv')
ball19  = pd.read_csv('/content/drive/MyDrive/Bowling Stats/BOWLING STATS - IPL_2019.csv')
ball20  = pd.read_csv('/content/drive/MyDrive/Bowling Stats/BOWLING STATS - IPL_2020.csv')
ball21  = pd.read_csv('/content/drive/MyDrive/Bowling Stats/BOWLING STATS - IPL_2021.csv')
ball22  = pd.read_csv('/content/drive/MyDrive/Bowling Stats/BOWLING STATS - IPL_2022.csv')
ball16['Year'] = 2016
ball17['Year'] = 2017
ball18['Year'] = 2018
ball19['Year'] = 2019
ball20['Year'] = 2020
ball21['Year'] = 2021
ball22['Year'] = 2022
#ball = pd.concat([ball16, ball17, ball18, ball19, ball20, ball21, ball22])
#ball

# %% [markdown]
# **ANALYSIS ON BATTERS**

# %%
bat.head()
# Out:
#    POS          Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0    1     Virat Kohli   16    16   4   973   113  81.08  640  152.03    4
# 1    2    David Warner   17    17   3   848   93*  60.57  560  151.42    0
# 2    3  AB de Villiers   16    16   3   687  129*  52.84  407  168.79    1
# 3    4  Gautam Gambhir   15    15   2   501   90*  38.53  411  121.89    0
# 4    5  Shikhar Dhawan   17    17   4   501   82*  38.53  429  116.78    0
#
#    50  4s  6s  Year
# 0   7  83  38  2016
# 1   9  88  31  2016
# 2   6  57  37  2016
# 3   5  54   6  2016
# 4   4  51   8  2016

# %%
bat.ndim
# Out:
# 2

# %%
bat.columns
# Out:
# Index(['POS', 'Player', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Avg', 'BF', 'SR',
#        '100', '50', '4s', '6s', 'Year'],
#       dtype='object')

# %%
bat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1005 entries, 0 to 161
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POS     1005 non-null   int64
#  1   Player  1005 non-null   object
#  2   Mat     1005 non-null   int64
#  3   Inns    1005 non-null   int64
#  4   NO      1005 non-null   int64
#  5   Runs    1005 non-null   int64
#  6   HS      1005 non-null   object
#  7   Avg     1005 non-null   object
#  8   BF      1005 non-null   int64
#  9   SR      1005 non-null   float64
#  10  100     1005 non-null   int64
#  11  50      1005 non-null   int64
#  12  4s      1005 non-null   int64
#  13  6s      1005 non-null   int64
#  14  Year    1005 non-null   int64
# dtypes: float64(1), int64(11), object(3)
# memory usage: 125.6+ KB

# %%
bat.isnull().sum()
# Out:
# POS       0
# Player    0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Avg       0
# BF        0
# SR        0
# 100       0
# 50        0
# 4s        0
# 6s        0
# Year      0
# dtype: int64

# %%
bat.shape
# Out:
# (1005, 15)

# %%
bat.describe()
# Out:
#                POS          Mat         Inns           NO         Runs  \
# count  1005.000000  1005.000000  1005.000000  1005.000000  1005.000000
# mean     72.569154     9.005970     6.562189     1.530348   132.156219
# std      41.970802     4.957585     4.870981     1.622281   162.894059
# min       1.000000     1.000000     1.000000     0.000000     0.000000
# 25%      36.000000     5.000000     2.000000     0.000000    10.000000
# 50%      72.000000     9.000000     5.000000     1.000000    55.000000
# 75%     108.000000    14.000000    11.000000     2.000000   217.000000
# max     162.000000    17.000000    17.000000    10.000000   973.000000
#
#                 BF           SR          100           50           4s  \
# count  1005.000000  1005.000000  1005.000000  1005.000000  1005.000000
# mean     99.535323   112.208577     0.039801     0.717413    11.633831
# std     116.450484    48.040814     0.264816     1.338871    15.730210
# ...

# %% [markdown]
# A high standard deviation in this case suggests that there's a relatively wide range of "not out" counts among players. Some players might have a higher number of not outs compared to the average, while others might have fewer.
#
# For example, if the standard deviation was very low, it would imply that most players have a very similar number of not outs, and there's little variability in this aspect of player performance. On the other hand, a higher standard deviation indicates that players' "not out" counts vary more widely.
#
# In summary, a mean of 1.53 and a standard deviation of 1.62 suggest that players' "not out" counts are somewhat spread out around the mean, with some players having more frequent "not outs" and others having fewer.
#
# *** if the standard deviation was very low (close to 0), it would imply that most players have played a very similar number of innings, and there's little variability in their innings. On the other hand, a higher standard deviation indicates that players' innings vary more widely, and some players might have played significantly more or fewer innings compared to the average.***

# %% [markdown]
# **overall performance of players **

# %%
bat16.shape
# Out:
# (136, 15)

# %%
print(bat17.shape)
print(bat18.shape)

print(bat19.shape)

print(bat20.shape)

print(bat21.shape)

print(bat22.shape)
# Out:
# (143, 15)
# (138, 15)
# (144, 15)
# (133, 15)
# (149, 15)
# (162, 15)

# %%
bat.columns
# Out:
# Index(['POS', 'Player', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Avg', 'BF', 'SR',
#        '100', '50', '4s', '6s', 'Year'],
#       dtype='object')

# %% [markdown]
# **Filter the data for batters who have played at least 10 matches.**

# %%
atleat_10_matches = bat.loc[bat['Mat']>10]
atleat_10_matches['Player'].unique()
# Out:
# array(['Virat Kohli', 'David Warner', 'AB de Villiers', 'Gautam Gambhir',
#        'Shikhar Dhawan', 'Rohit Sharma', 'Ajinkya Rahane', 'Murali Vijay',
#        'Quinton de Kock', 'Suresh Raina', 'KL Rahul', 'Robin Uthappa',
#        'Aaron Finch', 'Yusuf Pathan', 'Karun Nair', 'Brendon McCullum',
#        'Dinesh Karthik', 'Ambati Rayudu', 'Dwayne Smith', 'Sanju Samson',
#        'MS Dhoni', 'Wriddhiman Saha', 'Jos Buttler', 'Manish Pandey',
#        'Krunal Pandya', 'Kieron Pollard', 'Chris Morris',
#        'Ravindra Jadeja', 'Andre Russell', 'Suryakumar Yadav',
#        'Moises Henriques', 'Glenn Maxwell', 'Shane Watson',
#        'David Miller', 'Thisara Perera', 'Deepak Hooda', 'Naman Ojha',
#        'Sachin Baby', 'Axar Patel', 'Dwayne Bravo', 'Harbhajan Singh',
#        'Stuart Binny', 'Hardik Pandya', 'Bhuvneshwar Kumar',
#        'Ravichandran Ashwin', 'Mitchell McClenaghan', 'Mohit Sharma',
#        'Tim Southee', 'Praveen Kumar', 'Piyush Chawla', 'Dhawal Kulkarni',
# ...

# %%
bat16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POS     136 non-null    int64
#  1   Player  136 non-null    object
#  2   Mat     136 non-null    int64
#  3   Inns    136 non-null    int64
#  4   NO      136 non-null    int64
#  5   Runs    136 non-null    int64
#  6   HS      136 non-null    object
#  7   Avg     136 non-null    float64
#  8   BF      136 non-null    int64
#  9   SR      136 non-null    float64
#  10  100     136 non-null    int64
#  11  50      136 non-null    int64
#  12  4s      136 non-null    int64
#  13  6s      136 non-null    int64
#  14  Year    136 non-null    int64
# dtypes: float64(2), int64(11), object(2)
# memory usage: 16.1+ KB

# %% [markdown]
# coverting the hs data type and cleaning the data

# %%
def clean(year):

  year['HS'] = year['HS'].str.replace('*', '')
  year['HS'] = year['HS'].astype(int)

  year['Avg'] = year['Avg'].astype(str)
  year['Avg'] = year['Avg'].str.replace('-', '0')
  year['Avg'] = year['Avg'].astype(float)

  return year

bat = clean(bat)

bat16 = clean(bat16)
bat17 = clean(bat17)
bat18 = clean(bat18)
bat19 = clean(bat19)
bat20 = clean(bat20)
bat21 = clean(bat21)
bat22 = clean(bat22)
# Out:
# <ipython-input-155-1fce40482cce>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   year['HS'] = year['HS'].str.replace('*', '')

# %%
bat16
# Out:
#      POS          Player  Mat  Inns  NO  Runs   HS    Avg   BF      SR  100  \
# 0      1     Virat Kohli   16    16   4   973  113  81.08  640  152.03    4
# 1      2    David Warner   17    17   3   848   93  60.57  560  151.42    0
# 2      3  AB de Villiers   16    16   3   687  129  52.84  407  168.79    1
# 3      4  Gautam Gambhir   15    15   2   501   90  38.53  411  121.89    0
# 4      5  Shikhar Dhawan   17    17   4   501   82  38.53  429  116.78    0
# ..   ...             ...  ...   ...  ..   ...  ...    ...  ...     ...  ...
# 131  132   Swapnil Singh    1     1   0     0    0   0.00    1    0.00    0
# 132  133    Unmukt Chand    1     1   0     0    0   0.00    4    0.00    0
# 133  134      Adam Zampa    5     1   0     0    0   0.00    1    0.00    0
# 134  135  Shivil Kaushik    7     2   1     0    0   0.00    1    0.00    0
# 135  136  Murugan Ashwin   10     1   0     0    0   0.00    1    0.00    0
#
#      50  4s  6s  Year
# 0     7  83  38  2016
# ...

# %%
bat
# Out:
#      POS               Player  Mat  Inns  NO  Runs   HS    Avg   BF      SR  \
# 0      1          Virat Kohli   16    16   4   973  113  81.08  640  152.03
# 1      2         David Warner   17    17   3   848   93  60.57  560  151.42
# 2      3       AB de Villiers   16    16   3   687  129  52.84  407  168.79
# 3      4       Gautam Gambhir   15    15   2   501   90  38.53  411  121.89
# 4      5       Shikhar Dhawan   17    17   4   501   82  38.53  429  116.78
# ..   ...                  ...  ...   ...  ..   ...  ...    ...  ...     ...
# 157  158     Fazalhaq Farooqi    3     1   1     2    2   0.00    8   25.00
# 158  159   Jagadeesha Suchith    5     2   0     2    2   1.00    8   25.00
# 159  160          Tim Southee    9     5   1     2    1   0.50   12   16.66
# 160  161  Nathan Coulter-Nile    1     1   1     1    1   0.00    2   50.00
# 161  162        Anrich Nortje    6     1   1     1    1   0.00    6   16.66
#
#      100  50  4s  6s  Year
# 0      4   7  83  38  2016
# ...

# %% [markdown]
# **Calculate the batting average, strike rate, and number of fours and sixes for each batter.**

# %%
average = bat.groupby('Player')['Avg'].agg(['mean']).reset_index()
#average = average.rename(columns = {'Player': 'Player', 'mean': 'Mean'})
best_avg = average.where(average['mean'] > 25).dropna()
print(best_avg)
"""
 Cause the average around 25 to 30 might be considered good
 """
figure = plt.figure(figsize = (20, 10))
plt.barh(best_avg['mean'], best_avg['Player'])
plt.show()
# Out:
#               Player       mean
# 0     AB de Villiers  42.345000
# 5    Abhishek Sharma  25.692000
# 9      Aiden Markram  38.415000
# 18     Ambati Rayudu  29.771429
# 20     Andre Russell  31.431667
# ..               ...        ...
# 324   Venkatesh Iyer  28.830000
# 325    Vijay Shankar  27.405000
# 327      Virat Kohli  41.030000
# 332  Wriddhiman Saha  28.281429
# 334     Yusuf Pathan  33.070000
#
# [75 rows x 2 columns]

# %%
bat.columns
# Out:
# Index(['POS', 'Player', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Avg', 'BF', 'SR',
#        '100', '50', '4s', '6s', 'Year'],
#       dtype='object')

# %%
strike_rate = bat.groupby('Player')['SR'].agg(['mean']).reset_index()
best_strike = strike_rate.where(strike_rate['mean'] > 50).dropna()

print(best_strike)
"""
 Cause the average around 50 might be considered good
 """
figure = plt.figure(figsize = (20, 10))
plt.barh(best_strike['mean'], best_strike['Player'])
plt.show()
# Out:
#                 Player        mean
# 0       AB de Villiers  156.153333
# 1          Aaron Finch  136.744000
# 2          Abdul Samad  118.493333
# 4      Abhinav Manohar  144.000000
# 5      Abhishek Sharma  136.292000
# ..                 ...         ...
# 331  Washington Sundar  101.423333
# 332    Wriddhiman Saha  127.165714
# 333   Yashasvi Jaiswal  124.030000
# 334       Yusuf Pathan  122.195000
# 335       Yuvraj Singh  123.477500
#
# [297 rows x 2 columns]

# %% [markdown]
# Murge the data on the basis of seasons

# %%
batting_list = [bat16,bat17,bat18,bat19,bat20,bat21,bat22]
def combineddata(list_data):
  #first of all we check the no of season played by each player
  season_count = pd.concat(list_data)['Player'].value_counts().reset_index()
  #to rename the column name
  season_count = season_count.rename(columns={'Player':'Seasons','index':'Player'})
  #to group the data on the basis of players
  alldata = pd.concat(list_data).groupby(['Player']).sum().reset_index()
  # to merge the season_count with alldata
  all_data = alldata.merge(season_count, on='Player',how='left')
  return all_data

bat = combineddata(batting_list)
bat
# Out:
#                Player  POS  Mat  Inns  NO  Runs   HS     Avg    BF      SR  \
# 0      AB de Villiers   97   80    77  17  2592  539  254.07  1629  936.92
# 1         Aaron Finch  188   53    51   4  1180  302  120.49   881  683.72
# 2         Abdul Samad  255   25    20   4   226   65   36.53   159  355.48
# 3      Abhijeet Tomar  149    1     1   0     4    4    4.00     8   50.00
# 4     Abhinav Manohar   70    8     7   1   108   43   18.00    75  144.00
# ..                ...  ...  ...   ...  ..   ...  ...     ...   ...     ...
# 333  Yashasvi Jaiswal  132   23    23   0   547  152   64.03   406  372.09
# 334      Yusuf Pathan  166   55    45  20   804  183  132.28   608  488.78
# 335      Yuvraj Singh  180   34    31   3   651  187   89.55   504  493.91
# 336  Yuzvendra Chahal  733   88    16   9    35   22   13.33    84  220.36
# 337       Zaheer Khan  241   23     5   2    10    6    7.00    26   76.91
#
#      100  50   4s   6s   Year  Seasons
# ...

# %% [markdown]
# Finding avg and sr on the basis of seasons

# %%
def filter(all_data):
  all_data['Avg'] = round(all_data['Avg'] / all_data['Seasons'], 2)
  all_data['SR'] = round(all_data['SR'] / all_data['Seasons'], 2)
  return all_data

bat = filter(bat)
bat
# Out:
#                Player  POS  Mat  Inns  NO  Runs   HS    Avg    BF      SR  \
# 0      AB de Villiers   97   80    77  17  2592  539  42.34  1629  156.15
# 1         Aaron Finch  188   53    51   4  1180  302  24.10   881  136.74
# 2         Abdul Samad  255   25    20   4   226   65  12.18   159  118.49
# 3      Abhijeet Tomar  149    1     1   0     4    4   4.00     8   50.00
# 4     Abhinav Manohar   70    8     7   1   108   43  18.00    75  144.00
# ..                ...  ...  ...   ...  ..   ...  ...    ...   ...     ...
# 333  Yashasvi Jaiswal  132   23    23   0   547  152  21.34   406  124.03
# 334      Yusuf Pathan  166   55    45  20   804  183  33.07   608  122.20
# 335      Yuvraj Singh  180   34    31   3   651  187  22.39   504  123.48
# 336  Yuzvendra Chahal  733   88    16   9    35   22   2.22    84   36.73
# 337       Zaheer Khan  241   23     5   2    10    6   3.50    26   38.46
#
#      100  50   4s   6s   Year  Seasons
# 0      1  25  195  148  12111        6
# ...

# %%
bat.drop(columns = ['POS'], axis = 1, inplace = True)

# %%
bat
# Out:
#                Player  Mat  Inns  NO  Runs   HS    Avg    BF      SR  100  50  \
# 0      AB de Villiers   80    77  17  2592  539  42.34  1629  156.15    1  25
# 1         Aaron Finch   53    51   4  1180  302  24.10   881  136.74    0   9
# 2         Abdul Samad   25    20   4   226   65  12.18   159  118.49    0   0
# 3      Abhijeet Tomar    1     1   0     4    4   4.00     8   50.00    0   0
# 4     Abhinav Manohar    8     7   1   108   43  18.00    75  144.00    0   0
# ..                ...  ...   ...  ..   ...  ...    ...   ...     ...  ...  ..
# 333  Yashasvi Jaiswal   23    23   0   547  152  21.34   406  124.03    0   3
# 334      Yusuf Pathan   55    45  20   804  183  33.07   608  122.20    0   4
# 335      Yuvraj Singh   34    31   3   651  187  22.39   504  123.48    0   3
# 336  Yuzvendra Chahal   88    16   9    35   22   2.22    84   36.73    0   0
# 337       Zaheer Khan   23     5   2    10    6   3.50    26   38.46    0   0
#
#       4s   6s   Year  Seasons
# ...

# %%
bat.describe()
# Out:
#               Mat        Inns          NO         Runs          HS  \
# count  338.000000  338.000000  338.000000   338.000000  338.000000
# mean    26.778107   19.511834    4.550296   392.949704  103.869822
# std     27.978179   24.733623    6.076087   687.152707  143.619513
# min      1.000000    1.000000    0.000000     0.000000    0.000000
# 25%      5.000000    3.000000    1.000000    15.250000   11.250000
# 50%     14.000000    9.000000    2.000000    68.000000   37.500000
# 75%     41.750000   23.000000    6.000000   408.500000  138.500000
# max    110.000000  110.000000   42.000000  3663.000000  634.000000
#
#               Avg           BF          SR         100          50  \
# count  338.000000   338.000000  338.000000  338.000000  338.000000
# mean    15.131331   295.955621  106.106036    0.118343    2.133136
# std     12.240183   503.314015   43.539426    0.531685    4.846305
# min      0.000000     1.000000    0.000000    0.000000    0.000000
# ...

# %% [markdown]
# **Now Find the Top Players on the basis of  Different aspects**

# %% [markdown]
# Top 50 players on the basis of AVG

# %%
best_avg = bat.sort_values(by = 'Avg', ascending= False)[: 50]
best_avg
# Out:
#                  Player  Mat  Inns  NO  Runs   HS    Avg    BF      SR  100  \
# 142            KL Rahul   69    67  13  2945  493  54.27  2094  141.68    2
# 139           K L Rahul   15    15   3   616  103  51.33   455  135.38    2
# 69         David Warner   79    79  13  3356  553  49.92  2368  138.33    2
# 107         Hashim Amla   16    16   3   577  200  43.08   407  138.88    2
# 169            MS Dhoni  105    90  39  1991  403  42.91  1538  126.10    0
# 0        AB de Villiers   80    77  17  2592  539  42.34  1629  156.15    1
# 76         Devon Conway    7     7   1   252   87  42.00   173  145.66    0
# 327         Virat Kohli  100   100  13  3487  604  41.03  2618  130.23    5
# 257     Ruturaj Gaikwad   36    36   4  1207  272  40.88   926  127.81    1
# 119  Jagadeesan Narayan    2     2   1    40   39  40.00    37  108.10    0
# 136         Jos Buttler   82    81  10  2831  612  38.67  1891  149.39    5
# ...

# %%
figure = plt.figure(figsize = (15, 10))
plt.barh(best_avg['Player'], best_avg['Avg'], color = 'red')
plt.xlabel('Average')
plt.ylabel('Players')
plt.title('best 50 players on the basis of AVG')
plt.show()

# %% [markdown]
# Top 50 players on the basis of Runs

# %%
best_run = bat.sort_values(by = 'Runs', ascending = False)[:50]
best_run
# Out:
#                Player  Mat  Inns  NO  Runs   HS    Avg    BF      SR  100  50  \
# 281    Shikhar Dhawan  110   110  15  3663  634  38.56  2825  129.82    2  26
# 327       Virat Kohli  100   100  13  3487  604  41.03  2618  130.23    5  25
# 69       David Warner   79    79  13  3356  553  49.92  2368  138.33    2  32
# 142          KL Rahul   69    67  13  2945  493  54.27  2094  141.68    2  27
# 250      Rishabh Pant   98    97  15  2838  530  34.00  1918  146.63    1  15
# 136       Jos Buttler   82    81  10  2831  612  38.67  1891  149.39    5  15
# 265      Sanju Samson  100   100  10  2777  615  31.07  1984  140.38    3  13
# 0      AB de Villiers   80    77  17  2592  539  42.34  1629  156.15    1  25
# 254      Rohit Sharma   99    98   8  2494  504  28.15  1953  127.39    0  16
# 288      Shreyas Iyer   87    87  12  2337  495  29.64  1872  117.36    0  15
# 300  Suryakumar Yadav   93    84  11  2323  463  31.23  1699  134.98    0  16
# ...

# %%
best_run = bat.sort_values(by = 'Runs', ascending = False)[:50]
figure = plt.figure(figsize = (15, 10))
plt.barh(best_run['Player'], best_run['Runs'])
plt.xlabel('Runs')
plt.ylabel('Players')
plt.title('best 50 players on the basis of Runs')
plt.show()

# %% [markdown]
# On the basis of BF

# %%
ball_faced = bat.sort_values(by = ['BF'], ascending = False)[:50]
ball_faced
# Out:
#                Player  Mat  Inns  NO  Runs   HS    Avg    BF      SR  100  50  \
# 281    Shikhar Dhawan  110   110  15  3663  634  38.56  2825  129.82    2  26
# 327       Virat Kohli  100   100  13  3487  604  41.03  2618  130.23    5  25
# 69       David Warner   79    79  13  3356  553  49.92  2368  138.33    2  32
# 142          KL Rahul   69    67  13  2945  493  54.27  2094  141.68    2  27
# 265      Sanju Samson  100   100  10  2777  615  31.07  1984  140.38    3  13
# 254      Rohit Sharma   99    98   8  2494  504  28.15  1953  127.39    0  16
# 250      Rishabh Pant   98    97  15  2838  530  34.00  1918  146.63    1  15
# 136       Jos Buttler   82    81  10  2831  612  38.67  1891  149.39    5  15
# 288      Shreyas Iyer   87    87  12  2337  495  29.64  1872  117.36    0  15
# 18      Ambati Rayudu   92    85  14  2199  506  29.77  1737  125.77    1  11
# 300  Suryakumar Yadav   93    84  11  2323  463  31.23  1699  134.98    0  16
# ...

# %%
figure = plt.figure(figsize = (15, 10))
plt.barh(ball_faced['Player'], ball_faced['BF'], color = 'skyBlue')
plt.xlabel('ball faced')
plt.ylabel('Players')
plt.title('best 50 players on the basis of ball faced')
plt.show()

# %%
b = bat.sort_values(by=['BF','SR'], ascending=False)[:30][::-1]

# %% [markdown]
# top 30 players with most 6s

# %%
b = bat.sort_values(by='6s', ascending=False)[:50]
b
# Out:
#                Player  Mat  Inns  NO  Runs   HS    Avg    BF      SR  100  50  \
# 20      Andre Russell   76    65  13  1649  356  31.43   927  170.99    0   7
# 0      AB de Villiers   80    77  17  2592  539  42.34  1629  156.15    1  25
# 136       Jos Buttler   82    81  10  2831  612  38.67  1891  149.39    5  15
# 250      Rishabh Pant   98    97  15  2838  530  34.00  1918  146.63    1  15
# 265      Sanju Samson  100   100  10  2777  615  31.07  1984  140.38    3  13
# 53        Chris Gayle   60    60   4  1766  501  31.54  1248  139.35    1  13
# 142          KL Rahul   69    67  13  2945  493  54.27  2094  141.68    2  27
# 155    Kieron Pollard   96    86  27  1661  426  29.71  1137  145.76    0   8
# 69       David Warner   79    79  13  3356  553  49.92  2368  138.33    2  32
# 209       Nitish Rana   91    85   8  2181  500  29.30  1625  135.22    0  15
# 327       Virat Kohli  100   100  13  3487  604  41.03  2618  130.23    5  25
# ...

# %%
figure = plt.figure(figsize=(15,10))
plt.barh(b['Player'],b['6s'], color = 'brown')
plt.title('top 50 players with most sixes')
plt.xlabel('No of 6s')
plt.ylabel('Player name')
plt.plot()
# Out:
# []

# %% [markdown]
# top 30 players with most 6s

# %%
b = bat.sort_values(by='4s', ascending=False)[:50]
b
# Out:
#                Player  Mat  Inns  NO  Runs   HS    Avg    BF      SR  100  50  \
# 281    Shikhar Dhawan  110   110  15  3663  634  38.56  2825  129.82    2  26
# 69       David Warner   79    79  13  3356  553  49.92  2368  138.33    2  32
# 327       Virat Kohli  100   100  13  3487  604  41.03  2618  130.23    5  25
# 136       Jos Buttler   82    81  10  2831  612  38.67  1891  149.39    5  15
# 250      Rishabh Pant   98    97  15  2838  530  34.00  1918  146.63    1  15
# 142          KL Rahul   69    67  13  2945  493  54.27  2094  141.68    2  27
# 300  Suryakumar Yadav   93    84  11  2323  463  31.23  1699  134.98    0  16
# 254      Rohit Sharma   99    98   8  2494  504  28.15  1953  127.39    0  16
# 265      Sanju Samson  100   100  10  2777  615  31.07  1984  140.38    3  13
# 80     Dinesh Karthik  107   102  33  2169  431  33.52  1519  142.85    0  11
# 10     Ajinkya Rahane   77    73   6  1879  416  24.49  1543  115.79    1  11
# ...

# %%
figure = plt.figure(figsize=(15,10))
plt.barh(b['Player'],b['4s'], color = 'brown')
plt.title('top 50 players with most sixes')
plt.xlabel('No of 4s')
plt.ylabel('Player name')
plt.plot()
# Out:
# []

# %% [markdown]
# 50s

# %%
b = bat.sort_values(by='50', ascending=False)[:20]
s = b['50']>0
b = b[s]
b
# Out:
#                Player  Mat  Inns  NO  Runs   HS    Avg    BF      SR  100  50  \
# 69       David Warner   79    79  13  3356  553  49.92  2368  138.33    2  32
# 142          KL Rahul   69    67  13  2945  493  54.27  2094  141.68    2  27
# 281    Shikhar Dhawan  110   110  15  3663  634  38.56  2825  129.82    2  26
# 0      AB de Villiers   80    77  17  2592  539  42.34  1629  156.15    1  25
# 327       Virat Kohli  100   100  13  3487  604  41.03  2618  130.23    5  25
# 146   Kane Williamson   74    73  16  2070  483  35.34  1640  122.28    0  18
# 174     Manish Pandey   83    77  17  2077  468  35.05  1649  124.52    0  16
# 254      Rohit Sharma   99    98   8  2494  504  28.15  1953  127.39    0  16
# 300  Suryakumar Yadav   93    84  11  2323  463  31.23  1699  134.98    0  16
# 90     Faf du Plessis   55    54   6  1854  422  32.79  1396  128.22    0  16
# 288      Shreyas Iyer   87    87  12  2337  495  29.64  1872  117.36    0  15
# ...

# %%
plt.figure(figsize=(15,8))
plt.pie(b['50'], labels=b['Player'], autopct=lambda p: '{:.0f}'.format(p * sum(b['50']) / 100),textprops={'fontsize': 10, 'color': 'black'})
plt.title('top 20 player with most numbers of 50s')
plt.show()

# %% [markdown]
# 100s

# %%
b = bat.sort_values(by='100', ascending=False)[:20]
s = b['50']>0
b = b[s]
b
# Out:
#                Player  Mat  Inns  NO  Runs   HS    Avg    BF      SR  100  50  \
# 327       Virat Kohli  100   100  13  3487  604  41.03  2618  130.23    5  25
# 136       Jos Buttler   82    81  10  2831  612  38.67  1891  149.39    5  15
# 265      Sanju Samson  100   100  10  2777  615  31.07  1984  140.38    3  13
# 45         Ben Stokes   43    42   6   920  301  21.83   684  106.29    2   2
# 142          KL Rahul   69    67  13  2945  493  54.27  2094  141.68    2  27
# 139         K L Rahul   15    15   3   616  103  51.33   455  135.38    2   4
# 281    Shikhar Dhawan  110   110  15  3663  634  38.56  2825  129.82    2  26
# 274      Shane Watson   67    65   5  1502  356  23.71  1130  125.56    2   7
# 69       David Warner   79    79  13  3356  553  49.92  2368  138.33    2  32
# 107       Hashim Amla   16    16   3   577  200  43.08   407  138.88    2   3
# 53        Chris Gayle   60    60   4  1766  501  31.54  1248  139.35    1  13
# ...

# %%
plt.figure(figsize=(15,8))
plt.pie(b['100'], labels=b['Player'], autopct=lambda p: '{:.0f}'.format(p * sum(b['100']) / 100),textprops={'fontsize': 10, 'color': 'black'})
plt.title('top 20 player with most numbers of 100s')
plt.show()

# %% [markdown]
# 30 players on the basis of bf and strike

# %%
b = bat.sort_values(by=['BF','SR'] , ascending=False)[:30]
b
# Out:
#                Player  Mat  Inns  NO  Runs   HS    Avg    BF      SR  100  50  \
# 281    Shikhar Dhawan  110   110  15  3663  634  38.56  2825  129.82    2  26
# 327       Virat Kohli  100   100  13  3487  604  41.03  2618  130.23    5  25
# 69       David Warner   79    79  13  3356  553  49.92  2368  138.33    2  32
# 142          KL Rahul   69    67  13  2945  493  54.27  2094  141.68    2  27
# 265      Sanju Samson  100   100  10  2777  615  31.07  1984  140.38    3  13
# 254      Rohit Sharma   99    98   8  2494  504  28.15  1953  127.39    0  16
# 250      Rishabh Pant   98    97  15  2838  530  34.00  1918  146.63    1  15
# 136       Jos Buttler   82    81  10  2831  612  38.67  1891  149.39    5  15
# 288      Shreyas Iyer   87    87  12  2337  495  29.64  1872  117.36    0  15
# 18      Ambati Rayudu   92    85  14  2199  506  29.77  1737  125.77    1  11
# 300  Suryakumar Yadav   93    84  11  2323  463  31.23  1699  134.98    0  16
# ...

# %%
players = b['Player']
avg = b['BF']
sr = b['SR']

x = np.arange(len(players))
plt.figure(figsize=(15,10))
plt.bar(x, avg, width=0.5 ,color = 'Red') # x+0.2
plt.bar(x, sr, width=0.5, color = 'Black') # x-0.2 or any
plt.xticks(x,players,rotation=90)
plt.xlabel('player name')
plt.ylabel('count')
plt.title('Avg vs Strike rate')
plt.legend(['Average','Strike rate'])
plt.plot()
# Out:
# []

# %% [markdown]
#  30 players on the basis of run scored vs balls faced

# %%
b = bat.sort_values(by='BF', ascending=False)[:30]
b
# Out:
#                Player  Mat  Inns  NO  Runs   HS    Avg    BF      SR  100  50  \
# 281    Shikhar Dhawan  110   110  15  3663  634  38.56  2825  129.82    2  26
# 327       Virat Kohli  100   100  13  3487  604  41.03  2618  130.23    5  25
# 69       David Warner   79    79  13  3356  553  49.92  2368  138.33    2  32
# 142          KL Rahul   69    67  13  2945  493  54.27  2094  141.68    2  27
# 265      Sanju Samson  100   100  10  2777  615  31.07  1984  140.38    3  13
# 254      Rohit Sharma   99    98   8  2494  504  28.15  1953  127.39    0  16
# 250      Rishabh Pant   98    97  15  2838  530  34.00  1918  146.63    1  15
# 136       Jos Buttler   82    81  10  2831  612  38.67  1891  149.39    5  15
# 288      Shreyas Iyer   87    87  12  2337  495  29.64  1872  117.36    0  15
# 18      Ambati Rayudu   92    85  14  2199  506  29.77  1737  125.77    1  11
# 300  Suryakumar Yadav   93    84  11  2323  463  31.23  1699  134.98    0  16
# ...

# %%
player = b['Player']
runs = b['Runs']
bf = b['BF']

# Create a numerical range for x-coordinates

x = np.arange(len(player))
plt.figure(figsize = (15, 10))
plt.bar(x, runs, width = 0.5, color = 'red', label='Runs')
plt.bar(x, bf, width = 0.5, color = 'black', label = 'Balls Faced')
plt.xticks(x, player, rotation = 90)
plt.xlabel('Player')
plt.ylabel('Count')
plt.title('Runs and Balls Faced Comparison')
plt.legend()
plt.show()

# %% [markdown]
# # EDA for Bowlling data

# %%
ball16
# Out:
#     POS                Player  Mat  Inns  Ov  Runs  Wkts   BBI     Avg   Econ  \
# 0     1     Bhuvneshwar Kumar   17    17  66   490    23  5/19   21.30   7.42
# 1     2      Yuzvendra Chahal   13    13  49   401    21  4/25   19.09   8.15
# 2     3          Shane Watson   16    16  56   485    20  4/29   24.25   8.58
# 3     4       Dhawal Kulkarni   14    14  49   364    18  4/14   20.22   7.42
# 4     5  Mitchell McClenaghan   14    14  53   436    17  4/21   25.64   8.17
# ..  ...                   ...  ...   ...  ..   ...   ...   ...     ...    ...
# 81   82          Ashish Reddy    4     2   4    39     1  3/25   39.00  10.17
# 82   83     Rajagopal Sathish    4     3   6    59     1  1/11   59.00   9.83
# 83   84            Pawan Negi    8     5   9    84     1  4/18   84.00   9.33
# 84   85        Parveez Rasool    4     4  14   129     1  1/20  129.00   9.21
# 85   86         Harshal Patel    5     5  14   147     1  5/27  147.00  10.50
#
#        SR  4w  5w  Year
# ...

# %%
bat16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POS     136 non-null    int64
#  1   Player  136 non-null    object
#  2   Mat     136 non-null    int64
#  3   Inns    136 non-null    int64
#  4   NO      136 non-null    int64
#  5   Runs    136 non-null    int64
#  6   HS      136 non-null    int64
#  7   Avg     136 non-null    float64
#  8   BF      136 non-null    int64
#  9   SR      136 non-null    float64
#  10  100     136 non-null    int64
#  11  50      136 non-null    int64
#  12  4s      136 non-null    int64
#  13  6s      136 non-null    int64
#  14  Year    136 non-null    int64
# dtypes: float64(2), int64(12), object(1)
# memory usage: 16.1+ KB

# %%
ball
# Out:
# [    POS                Player  Mat  Inns  Ov  Runs  Wkts   BBI     Avg   Econ  \
#  0     1     Bhuvneshwar Kumar   17    17  66   490    23  5/19   21.30   7.42
#  1     2      Yuzvendra Chahal   13    13  49   401    21  4/25   19.09   8.15
#  2     3          Shane Watson   16    16  56   485    20  4/29   24.25   8.58
#  3     4       Dhawal Kulkarni   14    14  49   364    18  4/14   20.22   7.42
#  4     5  Mitchell McClenaghan   14    14  53   436    17  4/21   25.64   8.17
#  ..  ...                   ...  ...   ...  ..   ...   ...   ...     ...    ...
#  81   82          Ashish Reddy    4     2   4    39     1  3/25   39.00  10.17
#  82   83     Rajagopal Sathish    4     3   6    59     1  1/11   59.00   9.83
#  83   84            Pawan Negi    8     5   9    84     1  4/18   84.00   9.33
#  84   85        Parveez Rasool    4     4  14   129     1  1/20  129.00   9.21
#  85   86         Harshal Patel    5     5  14   147     1  5/27  147.00  10.50
#
#         SR  4w  5w
# ...

# %%
def clean_data(df_data):
  df_data.drop(['POS'], axis=1, inplace=True) #removing pos and BBI column
  return df_data

ball16 = clean_data(ball16)
ball17 = clean_data(ball17)
ball18 = clean_data(ball18)
ball19 = clean_data(ball19)
ball20 = clean_data(ball20)
ball21 = clean_data(ball21)
ball22 = clean_data(ball22)

# %%
ball16
# Out:
#                   Player  Mat  Inns  Ov  Runs  Wkts   BBI     Avg   Econ  \
# 0      Bhuvneshwar Kumar   17    17  66   490    23  5/19   21.30   7.42
# 1       Yuzvendra Chahal   13    13  49   401    21  4/25   19.09   8.15
# 2           Shane Watson   16    16  56   485    20  4/29   24.25   8.58
# 3        Dhawal Kulkarni   14    14  49   364    18  4/14   20.22   7.42
# 4   Mitchell McClenaghan   14    14  53   436    17  4/21   25.64   8.17
# ..                   ...  ...   ...  ..   ...   ...   ...     ...    ...
# 81          Ashish Reddy    4     2   4    39     1  3/25   39.00  10.17
# 82     Rajagopal Sathish    4     3   6    59     1  1/11   59.00   9.83
# 83            Pawan Negi    8     5   9    84     1  4/18   84.00   9.33
# 84        Parveez Rasool    4     4  14   129     1  1/20  129.00   9.21
# 85         Harshal Patel    5     5  14   147     1  5/27  147.00  10.50
#
#        SR  4w  5w  Year
# 0   17.21   1   0  2016
# 1   14.04   1   0  2016
# ...

# %% [markdown]
# cobining the data

# %%
season = pd.concat(list_data)['Player'].value_counts().reset_index()
season
# Out:
#                  index  Player
# 0    Bhuvneshwar Kumar       7
# 1           Axar Patel       7
# 2      Ravindra Jadeja       7
# 3        Krunal Pandya       7
# 4     Yuzvendra Chahal       7
# ..                 ...     ...
# 222      Swapnil Singh       1
# 223    Shubham Agarwal       1
# 224        Munaf Patel       1
# 225       Yuvraj Singh       1
# 226      Dewald Brevis       1
#
# [227 rows x 2 columns]

# %%
list_data = [ball16, ball17, ball18, ball19, ball20, ball21, ball22]
def combine(data):
  season = pd.concat(list_data)['Player'].value_counts().reset_index()
  season = season.rename(columns = {'Player':'Seasons','index':'Player'})
  alldata = pd.concat(data).groupby(['Player']).sum().reset_index()
  alldata = alldata.merge(season, on = 'Player', how = 'left')
  return alldata

ball = combine(list_data)
ball
# Out:
# <ipython-input-283-5c73859cad4c>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   alldata = pd.concat(data).groupby(['Player']).sum().reset_index()
#                Player  Mat  Inns     Ov  Runs  Wkts     Avg   Econ      SR  \
# 0         Abdul Samad   12     3    7.0    96     1   96.00  13.71   42.00
# 1     Abhishek Sharma   19    14   22.0   176     7   82.50  26.00   57.00
# 2          Adam Milne    9     9   32.0   308     7  131.32  29.67   80.00
# 3          Adam Zampa   14    14   48.0   370    21   78.86  23.33   58.50
# 4       Aiden Markram   14     4    6.0    64     1   64.00  10.66   36.00
# ..                ...  ...   ...    ...   ...   ...     ...    ...     ...
# 222        Yash Dayal    9     9   32.0   296    11   26.90   9.25   17.45
# ...

# %%
def converting(df_data):
  df_data['Avg'] = round(df_data['Avg'] / df_data['Seasons'],2)
  df_data['SR'] = round(df_data['SR'] / df_data['Seasons'],2)
  return df_data

ball = converting(ball)

# %%
ball
# Out:
#                Player  Mat  Inns     Ov  Runs  Wkts    Avg   Econ     SR  4w  \
# 0         Abdul Samad   12     3    7.0    96     1  96.00  13.71  42.00   0
# 1     Abhishek Sharma   19    14   22.0   176     7  27.50  26.00  19.00   0
# 2          Adam Milne    9     9   32.0   308     7  43.77  29.67  26.67   0
# 3          Adam Zampa   14    14   48.0   370    21  26.29  23.33  19.50   0
# 4       Aiden Markram   14     4    6.0    64     1  64.00  10.66  36.00   0
# ..                ...  ...   ...    ...   ...   ...    ...    ...    ...  ..
# 222        Yash Dayal    9     9   32.0   296    11  26.90   9.25  17.45   0
# 223      Yusuf Pathan   45     9   12.0    88     3  29.33  22.75  24.00   0
# 224      Yuvraj Singh   12     2    2.0    22     1  22.00  11.00  12.00   0
# 225  Yuzvendra Chahal  101   101  369.0  2789   131  22.02  52.76  17.60   3
# 226       Zaheer Khan   23    23   83.0   650    20  32.50  15.50  25.15   0
#
#      5w   Year  Seasons
# ...

# %%
ball.describe()
# Out:
#               Mat        Inns          Ov         Runs        Wkts  \
# count  227.000000  227.000000  227.000000   227.000000  227.000000
# mean    23.299559   21.409692   70.934361   583.088106   20.634361
# std     23.777511   23.136656   82.979503   645.464175   25.048330
# min      1.000000    1.000000    0.300000     8.000000    1.000000
# 25%      6.000000    5.000000   16.000000   140.000000    3.500000
# 50%     13.000000   12.000000   35.000000   299.000000    9.000000
# 75%     35.000000   31.500000  107.500000   923.000000   30.000000
# max    103.000000  103.000000  394.200000  2823.000000  134.000000
#
#               Avg        Econ         SR          4w          5w  \
# count  227.000000  227.000000  227.00000  227.000000  227.000000
# mean    37.658987   23.230441   25.61793    0.330396    0.061674
# std     17.159497   15.583085   10.80349    0.729348    0.241094
# min      4.000000    3.750000    3.00000    0.000000    0.000000
# ...

# %% [markdown]
# top 50 bowlers most run scored

# %%
b = ball.sort_values(by = 'Runs', ascending=False)[:30]
b
# Out:
#                    Player  Mat  Inns     Ov  Runs  Wkts    Avg   Econ     SR  \
# 82         Jasprit Bumrah  103   103  394.2  2823   134  21.77  50.06  18.21
# 225      Yuzvendra Chahal  101   101  369.0  2789   131  22.02  52.76  17.60
# 200          Sunil Narine   93    92  357.0  2505    78  35.52  49.49  30.12
# 30      Bhuvneshwar Kumar   87    87  331.1  2491    92  33.00  52.23  26.24
# 129        Mohammad Shami   78    78  285.0  2443    91  34.04  62.18  22.45
# 167   Ravichandran Ashwin   87    87  311.0  2354    67  36.47  45.18  29.02
# 165           Rashid Khan   92    92  365.5  2333   112  20.87  38.28  19.61
# 188        Shardul Thakur   74    73  254.2  2302    81  29.13  53.92  19.44
# 23             Axar Patel   91    90  313.0  2286    71  39.04  51.68  31.32
# 209           Trent Boult   71    71  269.0  2239    83  31.56  60.02  21.95
# 168       Ravindra Jadeja   99    95  291.0  2218    63  41.18  53.98  31.17
# ...

# %%
figure = plt.figure(figsize=(15,10))
plt.barh(b['Player'], b['Runs'])
plt.xlabel('Runs')
plt.ylabel('Player name')
plt.title("top 50 bowlerswith most run scored")
plt.show()

# %%
b = ball.sort_values(by=['Avg'], ascending=False)[:50]
b
# Out:
#                   Player  Mat  Inns     Ov  Runs  Wkts     Avg   Econ     SR  \
# 148       Parveez Rasool    4     4   14.0   129     1  129.00   9.21  84.00
# 201         Suresh Raina   14     6   12.0   102     1  102.00   8.50  72.00
# 133     Moises Henriques   34    34   86.0   708    17   97.94  22.81  61.67
# 0            Abdul Samad   12     3    7.0    96     1   96.00  13.71  42.00
# 183        Shadab Jakati    6     6   20.0   178     2   89.00   8.90  60.00
# 107          Kyle Abbott    5     5   16.0   177     2   88.50  11.06  48.00
# 13          Ankit Sharma    3     3   11.0    84     1   84.00   7.63  66.00
# 43            Dale Steyn    5     5   19.0   202     5   75.12  20.02  41.00
# 101   Krishnappa Gowtham   28    28   80.0   661    18   74.54  34.85  51.05
# 14            Ankit Soni    7     6   18.0   144     2   72.00   7.92  54.50
# 121           Matt Henry    2     2    5.0    71     1   71.00  14.20  30.00
# ...

# %%
figure = plt.figure(figsize=(15,10))
plt.barh(b['Player'],b['Avg'])
plt.xlabel('Avg')
plt.ylabel('Player name')
plt.title('Top 50 with AVG')
plt.show()

# %% [markdown]
# Innings and matches

# %%
b = ball.sort_values(by='Inns', ascending=False)[:30][::-1]
b
# Out:
#                   Player  Mat  Inns     Ov  Runs  Wkts    Avg   Econ     SR  \
# 67         Harshal Patel   48    48  167.3  1437    67  43.46  65.14  26.92
# 221    Washington Sundar   51    49  153.0  1106    33  34.34  45.84  27.25
# 119       Marcus Stoinis   67    50  107.0  1048    34  41.68  69.78  25.49
# 155      Prasidh Krishna   51    51  189.3  1703    49  43.90  45.38  28.76
# 151        Piyush Chawla   54    53  173.0  1492    48  32.30  52.62  22.00
# 160         Rahul Chahar   55    54  196.4  1477    57  26.34  38.09  20.75
# 38          Chris Morris   54    54  194.0  1583    67  26.50  50.02  18.78
# 85        Jaydev Unadkat   56    56  198.0  1792    59  38.01  54.37  24.80
# 8            Amit Mishra   56    56  186.0  1402    55  24.91  45.16  19.81
# 104        Kuldeep Yadav   59    57  198.4  1655    61  42.17  49.51  31.05
# 212          Umesh Yadav   60    60  213.0  1772    71  27.19  42.17  19.01
# ...

# %%
players = b['Player']
matche = b['Mat']
Inn = b['Inns']

# Create a numerical range for x-coordinates
x = np.arange(len(players))

plt.figure(figsize=(15, 10))
plt.bar(x+0.20, matche, width=0.4, color='red', label='Matches')
plt.bar(x-0.20, Inn, width=0.4, color='black', label='Innings')
plt.xticks(x, players, rotation=90)  # Use player names as x-axis labels
plt.xlabel('Player')
plt.ylabel('Count')
plt.title('Innings and matches Comparison')
plt.legend()

plt.show()

# %%
b = ball.sort_values(by='4w', ascending=False)[:20]
s = b['4w']>0
b = b[s]
b
# Out:
#                Player  Mat  Inns     Ov  Runs  Wkts    Avg   Econ     SR  4w  \
# 93      Kagiso Rabada   63    63  237.0  1966    99  22.47  41.56  16.13   6
# 104     Kuldeep Yadav   59    57  198.4  1655    61  42.17  49.51  31.05   3
# 225  Yuzvendra Chahal  101   101  369.0  2789   131  22.02  52.76  17.60   3
# 38       Chris Morris   54    54  194.0  1583    67  26.50  50.02  18.78   3
# 10         Andrew Tye   30    30  114.0   979    42  42.31  47.52  25.10   3
# 9       Andre Russell   76    67  169.1  1574    73  22.56  56.33  14.47   2
# 110    Lasith Malinga   24    24   90.0   820    27  31.04  18.28  20.63   2
# 48      Deepak Chahar   61    61  215.0  1681    59  37.78  41.28  26.33   2
# 67      Harshal Patel   48    48  167.3  1437    67  43.46  65.14  26.92   2
# 212       Umesh Yadav   60    60  213.0  1772    71  27.19  42.17  19.01   2
# 8         Amit Mishra   56    56  186.0  1402    55  24.91  45.16  19.81   2
# ...

# %%
plt.figure(figsize=(15,8))
plt.pie(b['4w'], labels=b['Player'], autopct=lambda p: '{:.0f}'.format(p * sum(b['4w']) / 100),textprops={'fontsize': 10, 'color': 'black'})
plt.title('top 20 player with most numbers of 4w')
plt.show()

# %%
b = ball.sort_values(by='5w', ascending=False)[:20]
s = b['5w']>0
b = b[s]
b
# Out:
#                   Player  Mat  Inns     Ov  Runs  Wkts    Avg   Econ     SR  \
# 18        Arshdeep Singh   37    37  126.0  1054    40  29.51  35.64  20.08
# 9          Andre Russell   76    67  169.1  1574    73  22.56  56.33  14.47
# 213          Umran Malik   17    17   61.1   540    24  34.09  17.03  24.70
# 82        Jasprit Bumrah  103   103  394.2  2823   134  21.77  50.06  18.21
# 216  Varun Chakaravarthy   42    42  162.0  1171    42  34.04  33.59  24.50
# 30     Bhuvneshwar Kumar   87    87  331.1  2491    92  33.00  52.23  26.24
# 85        Jaydev Unadkat   56    56  198.0  1792    59  38.01  54.37  24.80
# 12         Ankit Rajpoot   27    27   84.0   779    23  45.97  46.26  28.05
# 10            Andrew Tye   30    30  114.0   979    42  42.31  47.52  25.10
# 220    Wanindu Hasaranga   16    16   57.0   430    26  16.53   7.54  13.15
# 7         Alzarri Joseph   12    12   38.0   351    13  26.10  18.83  17.19
# ...

# %%
plt.figure(figsize=(15,8))
plt.pie(b['5w'], labels=b['Player'], autopct=lambda p: '{:.0f}'.format(p * sum(b['5w']) / 100),textprops={'fontsize': 10, 'color': 'black'})
plt.title('top 20 player with most numbers of 5w')
plt.show()

# %%
b = ball.sort_values(by = 'Wkts', ascending=False)[:30]
b
# Out:
#                    Player  Mat  Inns     Ov  Runs  Wkts    Avg   Econ     SR  \
# 82         Jasprit Bumrah  103   103  394.2  2823   134  21.77  50.06  18.21
# 225      Yuzvendra Chahal  101   101  369.0  2789   131  22.02  52.76  17.60
# 165           Rashid Khan   92    92  365.5  2333   112  20.87  38.28  19.61
# 93          Kagiso Rabada   63    63  237.0  1966    99  22.47  41.56  16.13
# 30      Bhuvneshwar Kumar   87    87  331.1  2491    92  33.00  52.23  26.24
# 129        Mohammad Shami   78    78  285.0  2443    91  34.04  62.18  22.45
# 209           Trent Boult   71    71  269.0  2239    83  31.56  60.02  21.95
# 188        Shardul Thakur   74    73  254.2  2302    81  29.13  53.92  19.44
# 200          Sunil Narine   93    92  357.0  2505    78  35.52  49.49  30.12
# 54           Dwayne Bravo   70    70  238.2  2099    78  27.43  51.87  18.90
# 178        Sandeep Sharma   75    75  279.0  2179    75  39.39  54.89  29.94
# ...

# %%
figure = plt.figure(figsize=(15,10))
plt.barh(b['Player'],b['Wkts'])
plt.xlabel('Avg')
plt.ylabel('Player name')
plt.title('Top 30 with wkts')
plt.show()

# %% [markdown]
# Over

# %%
b = ball.sort_values(by = 'Ov', ascending=False)[:30]
b
# Out:
#                    Player  Mat  Inns     Ov  Runs  Wkts    Avg   Econ     SR  \
# 82         Jasprit Bumrah  103   103  394.2  2823   134  21.77  50.06  18.21
# 225      Yuzvendra Chahal  101   101  369.0  2789   131  22.02  52.76  17.60
# 165           Rashid Khan   92    92  365.5  2333   112  20.87  38.28  19.61
# 200          Sunil Narine   93    92  357.0  2505    78  35.52  49.49  30.12
# 30      Bhuvneshwar Kumar   87    87  331.1  2491    92  33.00  52.23  26.24
# 23             Axar Patel   91    90  313.0  2286    71  39.04  51.68  31.32
# 167   Ravichandran Ashwin   87    87  311.0  2354    67  36.47  45.18  29.02
# 168       Ravindra Jadeja   99    95  291.0  2218    63  41.18  53.98  31.17
# 129        Mohammad Shami   78    78  285.0  2443    91  34.04  62.18  22.45
# 178        Sandeep Sharma   75    75  279.0  2179    75  39.39  54.89  29.94
# 102         Krunal Pandya   98    93  278.0  2038    61  37.29  51.26  30.14
# ...

# %%
figure = plt.figure(figsize=(15,10))
plt.barh(b['Player'],b['Ov'])
plt.xlabel('Avg')
plt.ylabel('Player name')
plt.title('Top 30 with Over')
plt.show()
